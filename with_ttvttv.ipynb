# %%
# !pip install gtts gradio
# !brew install ffmpeg  # macOS (Homebrew)
# !pip install openai-whisper ffmpeg-python
# !pip install sounddevice
#!pip install git+https://github.com/openai/whisper.git

# %% [markdown]
# ** Import Libraries & Dependencies **

# %%
# Standard Libraries
import os
import re
import subprocess
import traceback
import pickle
import spacy
from collections import Counter

# Data Handling and Processing
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns  

# Scikit-Learn: Preprocessing and Model Selection
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# Scikit-Learn: Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
# Scikit-Learn: Evaluation Metrics
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score
)

# Scikit-Learn: Class Weights
from sklearn.utils.class_weight import compute_class_weight

# Scikit-Learn: Feature Engineering
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics.pairwise import cosine_similarity

# Transformers
from transformers import AutoModelForTokenClassification, AutoTokenizer
from transformers import pipeline   

# Imbalanced Data Handling
from imblearn.combine import SMOTEENN

# TensorFlow & Keras
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, Concatenate, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Joblib (for saving/loading models)
import joblib

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from itertools import combinations

import pandas as pd
from sklearn.preprocessing import LabelEncoder

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

import gradio as gr
import speech_recognition as sr
from gtts import gTTS

import datetime

import whisper
import sounddevice as sd  # Handles microphone input
import wave  # Built-in module for saving WAV files

# %% [markdown]
# ** Load the data **

# %%
# 1. Load and examine the data
disease_symptoms_data = pd.read_csv('Resources/disease_symptoms.csv')

# %% [markdown]
# ** Explore the data **

# %%
disease_symptoms_data.head()
# Out:
#      Disease                                           Symptoms
# 0    Malaria         fever, headache, weakness, cough, vomiting
# 1        Flu  fever, headache, runny nose, muscle aches, fat...
# 2    Measles   fever, red rash, conjunctivitis, cough, rhinitis
# 3  Pneumonia  sputum production, fever, chest pain, cough, c...
# 4   Tinnitus  hissing, buzzing, clicking, roaring, ringing i...

# %%
#list Symptoms
disease_symptoms_data['Symptoms'].unique()
# Out:
# array(['fever, headache, weakness, cough, vomiting',
#        'fever, headache, runny nose, muscle aches, fatigue',
#        'fever, red rash, conjunctivitis, cough, rhinitis',
#        'sputum production, fever, chest pain, cough, chills, fatigue, shortness of breath',
#        'hissing, buzzing, clicking, roaring, ringing in the ears',
#        'vomiting, headache, fatigue, agitation',
#        'frequent urination, inability to sleep through the night without urinating, urinary leakage, difficulty urinating',
#        'respiratory disorder, vomiting, rapid pulse, diarrhea, low blood pressure, malaise, runny nose, abdominal pain, eczema',
#        'hair loss, gradual thinning of hair',
#        'disorientation in time, memory loss',
#        'swollen tonsils, fever, difficulty swallowing, sore throat',
#        'headache, hot flashes, absence of menstruation',
#        'dry skin, hair loss, weight gain, sexual dysfunction, decreased muscle mass and strength, decreased testicular volume',
#        'breathing difficulty, nausea, malaise, anxiety, excessive sweating, vomiting',
#        'fever, headache, sweating, chills, swollen lymph nodes and difficulty swallowing, sore throat',
#        'infection or bleeding, extensive angioma, sudden appearance of an angioma',
#        'significant and constant weight loss, hair loss, constipation, anxiety, brittle nails, memory imbalance',
#        'malaise, fever, chills, lethargy',
#        'high blood pressure, nausea, headache, seizures, vomiting, lower back pain, swelling',
#        'breathing difficulty, choking sensation, tremors, cold sweats, right hand discomfort, rapid heartbeat, palpitations',
#        'paleness, shortness of breath on exertion, dizziness, palpitations, abnormal fatigue',
#        'pain, red and warm skin, skin swelling',
#        'fever, headache, general fatigue',
#        'joint crepitus, limited movement, joint swelling, deformation of affected joints',
#        'breathing difficulty, dry, sometimes chronic cough, excessive sweating, wheezing, pursed lips, shortness of breath',
#        'light sensitivity, headache, double vision, frequent squinting, eye fatigue, dizziness',
#        'insensitivity to noise, absent speech, distinctive gait, difficulty establishing contact',
#        'loss of appetite, vomiting, nausea, fever',
#        'abdominal cramps, complete absence of gas and stool, weight loss, diarrhea',
#        'pain, frequent urge to urinate, itching, eye involvement, inflammation, stinging',
#        'facial redness, heat sensation, excessive sweating',
#        'pain, fever, burning sensation in the chest, fatigue, breathing discomfort',
#        'sputum production, cough, shortness of breath',
#        'pain, redness of the skin, skin swelling',
#        'burning sensation in the sternum and throat, pain, acid reflux, bitter or sour taste in the throat and mouth',
#        'motor disorder, hesitation while speaking, use of synonyms, repetition of the same sound',
#        'pain, fever, nausea, chills, burning sensation',
#        'red lesions, skin lesions, flat pink macule, burning sensation, eczema',
#        'blood in urine, presence of bone metastasis, difficulty urinating',
#        'lower back pain, precancerous lesions, bleeding outside menstruation',
#        'fever, peritonitis, abdominal pain, weight loss',
#        'enlarged spleen, weight loss, diabetes, abdominal pain, jaundice',
#        'pain, respiratory infection, bloody sputum, cough, breathing discomfort',
#        'pain, thick white discharge, itching, inflammation of the glans, vulvar inflammation',
#        'respiratory infection, delayed wound healing, joint pain, weakness',
#        'pain, cavity presence, bad breath, gum swelling, black spot appearance',
#        'light sensitivity, color perception changes, double vision, white pupil, blurred vision',
#        'sense of terror, frightening dream, night waking due to fear or anxiety, excessive sweating',
#        'heavy sensation in affected areas, granular skin texture on buttocks, pressure sensitivity',
#        'abnormal fluid accumulation in the abdomen, digestive bleeding, jaundice, itching',
#        'popping sound, pain, bruising, walking difficulty, swelling',
#        'intestinal noises, hard stomach, intense, prolonged crying, bloating, unexplained agitation',
#        'pain, nausea, vomiting, breathing discomfort',
#        'fever, nausea, blood in urine, vomiting, burning urination, chills, abdominal pain',
#        'anemia, pain, fever, constipation, fatigue, diarrhea, bloating',
#        'light sensitivity, pain, itching, tearing, blurred vision, eye redness, gritty or burning eye sensation',
#        'straining during defecation, lower abdominal pain, hemorrhoids, absence of bowel movements for days, bloating',
#        'cough, sneezing, runny nose, mild fever',
#        'fever, headache, intense thirst, blurred vision, drowsiness, dizziness, sweating',
#        'fever, headache, nausea, throat irritation, fatigue, diarrhea, shortness of breath',
#        'skin lesions, itching, widespread itching',
#        'fever, rapid breathing, vomiting, inability to urinate, abdominal pain, bloody stool',
#        'gum swelling, gum redness, pain, bad breath, tooth sensitivity, bleeding',
#        'eye pain, halos around lights, nausea, blurred vision, vomiting, redness of the eye',
#        'pain, fever, redness, joint stiffness, swelling',
#        'pain, itching, bleeding, swelling, mucous discharge',
#        'nausea, dark urine, light stool, vomiting, abdominal pain, fatigue, jaundice',
#        'pain, burning sensation, bulge, swelling',
#        'pain, fever, itching, burning sensation, blisters',
#        'headache, nosebleeds, chest pain, dizziness, shortness of breath',
#        'nausea, fainting, blurred vision, dizziness, fatigue',
#        'dry skin, weight gain, cold intolerance, constipation, depression, fatigue',
#        'tremors, nervousness, weight loss, irritability, rapid heartbeat, sweating',
#        'waking up too early, difficulty falling asleep, daytime sleepiness, difficulty staying asleep',
#        'constipation, abdominal pain, mucus in stool, diarrhea, bloating',
#        'light stool, yellowing of the skin and eyes, dark urine, itching',
#        'throat discomfort, cough, hoarseness, loss of voice',
#        'fever, rash, hair loss, joint pain, chest pain, fatigue',
#        'fever, rash, headache, joint pain, neck stiffness, fatigue',
#        'irregular menstruation, hot flashes, mood swings, vaginal dryness, night sweats',
#        'nausea, headache, aura, vomiting, sensitivity to light and sound',
#        'muscle weakness, tingling, difficulty walking, fatigue, numbness',
#        'loss of height, bone fractures, back pain, stooped posture',
#        'fever, ear discharge, hearing loss, ear pain',
#        'pelvic pain, irregular menstruation, pain during intercourse, abdominal swelling',
#        'fever, nausea, vomiting, rapid pulse, abdominal pain',
#        'slow movement, tremors, rigidity, loss of automatic movements, postural instability',
#        'rapid heartbeat, chest pain, cough, shortness of breath',
#        'silvery scales, red patches of skin, burning sensation, itching',
#        'morning stiffness, joint pain, weight loss, fatigue, swelling',
#        'pimples, redness of the face, neck, and chest, eye irritation, visible blood vessels',
#        'tingling, pain, muscle weakness, numbness',
#        'fever, cough, nasal congestion, nasal discharge, facial pain',
#        'confusion, trouble speaking, weakness, sudden numbness, vision problems',
#        'rapid heartbeat, chest pain, dizziness, shortness of breath',
#        'pain, limited movement, swelling, stiffness',
#        'pain, fever, headache, swelling',
#        'pain, vaginal discharge, burning sensation, itching',
#        'nausea, weight loss, vomiting, abdominal pain, bloating',
#        'frequent urination, nocturia, urine leakage, sudden urge to urinate',
#        'fever, blood in urine, painful urination, frequent urination, back pain',
#        'redness, swelling, itching, hives',
#        'pain, vein swelling, leg heaviness, itching',
#        'vomiting, nausea, headache, dizziness',
#        'white patches on the skin, eye and mouth discoloration, hair whitening',
#        'rough to the touch, skin growths, black dots',
#        'headache, neck stiffness, dizziness, neck pain'], dtype=object)

# %% [markdown]
# ** Find a method to separate the symptoms from the disease column and create a new column for each symptom. **

# %%
# Expand the dataset while maintaining symptom relationships

def expand_dataset_simple(df):

    expanded_data = []
    
    for _, row in df.iterrows():
        disease = row['Disease']
        symptoms = row['Symptoms']
        
        # Clean symptoms
        symptoms = re.sub(r'[\[\]\'"]', '', symptoms)
        symptom_list = [s.strip().lower() for s in symptoms.split(',')]
        symptom_list = [s for s in symptom_list if s]
        
        # Original entry
        original_symptoms = ', '.join(symptom_list)
        expanded_data.append({
            'Disease': disease,
            'Symptoms': original_symptoms
        })
        # Create 5 variations for each disease
        for _ in range(5):
            if len(symptom_list) > 3:
                # Keep 80% of symptoms, randomly selected
                n_symptoms = max(3, int(0.8 * len(symptom_list)))
                selected_symptoms = np.random.choice(symptom_list, size=n_symptoms, replace=False)
            else:
                # For few symptoms, use all but in different order
                selected_symptoms = np.random.permutation(symptom_list)
            
            expanded_data.append({
                'Disease': disease,
                'Symptoms': ', '.join(selected_symptoms)
            })
    
    return pd.DataFrame(expanded_data)

# %% [markdown]
# ** Expand the dataset so lengths match so we can move forward with processing **

# %%
# Create expanded dataset
expanded_df = expand_dataset_simple(disease_symptoms_data)
print(f"Original dataset size: {len(disease_symptoms_data)}")
print(f"Expanded dataset size: {len(expanded_df)}")
# Out:
# Original dataset size: 108
# Expanded dataset size: 648

# %% [markdown]
# ** Increase the min/max samples **

# %%
# Print distribution of samples
disease_counts = expanded_df['Disease'].value_counts()
print("\nSamples per disease:")
print(f"Minimum samples: {disease_counts.min()}")
print(f"Maximum samples: {disease_counts.max()}")
print(f"Average samples: {disease_counts.mean():.1f}")
# Out:
# Samples per disease:
# Minimum samples: 6
# Maximum samples: 6
# Average samples: 6.0

# %% [markdown]
# ** Preprocess the data so the symptoms column  keeps together the words necesary to express common medical phrases, while removing the commas. **

# %%
# Preprocess and clean symptom text by removing stopwords and preserving important medical phrases
def preprocess_symptoms(text):

    if not isinstance(text, str):
        return ''


        # Define common medical phrases that should be kept together
    medical_phrases = [
        'pain in the chest',
        'chest pain',
        'shortness of breath',
        'ringing in the ears',
        'swelling of the joints',
        'pain in my right hand',
        'burning sensation in the chest',
        'shortness of breath on exertion',
        'difficulty in breathing',
        'loss of voice',
        'loss of height',
        'loss of appetite',
        'thinning of hair',
        'disorientation in time',
        'inability to sleep',
        'sensitivity to light',
        'burning sensation in the sternum',
        'bitter or sour taste',
        'difficulty establishing contact',
        'absence of gas',
        'absence of bowel movements',
        'bleeding outside menstruation',
        'difficulty breathing',
        'pain in the back',
        'back pain',
        'swelling of the joints',
        'joint swelling',
        'pain in the right hand',
        'right hand pain',
        'pain in the left hand',
        'left hand pain',
        'loss of appetite',
        'difficulty swallowing',
        'ringing in the ears',
        'blurred vision',
        'high blood pressure',
        'low blood pressure',
        'rapid heart rate',
        'irregular heartbeat',
        'muscle weakness',
        'chronic fatigue',
        'night sweats',
        'weight loss',
        'weight gain',
        'joint pain',
        'muscle pain',
        'sore throat',
        'runny nose',
        'stuffy nose',
        'abdominal pain',
        'stomach pain',
        'lower back pain',
        'upper back pain',
        'neck pain',
        'shoulder pain'
    ]
    
     
    # Sort phrases by length (longest first) to ensure longer phrases are matched before shorter ones
    medical_phrases.sort(key=len, reverse=True)

    # Clean the text
    text = re.sub(r'[\[\]\'\"]', '', text.lower())
    
    # Replace spaces with underscores in medical phrases
    for phrase in medical_phrases:
        if phrase in text:
            text = text.replace(phrase, phrase.replace(' ', '_'))

        # Split by commas and clean each symptom
    symptoms = [s.strip() for s in text.split(',')]
    
    # Define stopwords to remove (excluding those that might be important in medical context)
    stopwords = {'and', 'or', 'the', 'a', 'an', 'in', 'on', 'at', 'to', 'for', 'of', 'with', 'by'}
    
    # Process each symptom
    cleaned_symptoms = []
    for symptom in symptoms:
        # Skip empty symptoms
        if not symptom:
            continue

            
        # If symptom contains underscores (preserved phrase), keep as is
        if '_' in symptom:
            cleaned_symptoms.append(symptom)
            continue
            
        # Otherwise, split into words and remove stopwords
        words = symptom.split()
        words = [w for w in words if w not in stopwords]
        if words:
            cleaned_symptoms.append(' '.join(words))
    
    # Join all symptoms and replace underscores back with spaces
    result = ' '.join(cleaned_symptoms)
    for phrase in medical_phrases:
        result = result.replace(phrase.replace(' ', '_'), phrase)
    
    return result

# %% [markdown]
# ** Test to see if the preprocessing worked **

# %%
test_text = "pain in the chest, swelling of the joints, difficulty in breathing"
print("Original:", test_text)
print("Cleaned:", preprocess_symptoms(test_text))
# Out:
# Original: pain in the chest, swelling of the joints, difficulty in breathing
# Cleaned: pain in the chest swelling of the joints difficulty in breathing

# %% [markdown]
# **Expand the Symptoms column to produce a more balanced dataset since SMOTE and SMOTEEN were not effective.**

# %%
expanded_df.head(60)
# Out:
#              Disease                                           Symptoms
# 0            Malaria         fever, headache, weakness, cough, vomiting
# 1            Malaria                   headache, fever, cough, weakness
# 2            Malaria                headache, fever, weakness, vomiting
# 3            Malaria                   cough, weakness, headache, fever
# 4            Malaria                   fever, vomiting, weakness, cough
# 5            Malaria                   vomiting, fever, cough, headache
# 6                Flu  fever, headache, runny nose, muscle aches, fat...
# 7                Flu           muscle aches, fever, runny nose, fatigue
# 8                Flu           muscle aches, runny nose, fever, fatigue
# 9                Flu               fatigue, runny nose, fever, headache
# 10               Flu           fatigue, fever, runny nose, muscle aches
# 11               Flu        muscle aches, headache, runny nose, fatigue
# 12           Measles   fever, red rash, conjunctivitis, cough, rhinitis
# 13           Measles                   rhinitis, fever, red rash, cough
# 14           Measles             fever, rhinitis, conjunctivitis, cough
# 15           Measles             cough, rhinitis, fever, conjunctivitis
# 16           Measles             fever, conjunctivitis, rhinitis, cough
# 17           Measles             fever, red rash, cough, conjunctivitis
# 18         Pneumonia  sputum production, fever, chest pain, cough, c...
# 19         Pneumonia  chest pain, chills, fatigue, shortness of brea...
# 20         Pneumonia  shortness of breath, sputum production, cough,...
# 21         Pneumonia  chest pain, shortness of breath, sputum produc...
# 22         Pneumonia  cough, chest pain, sputum production, fever, c...
# 23         Pneumonia  sputum production, chest pain, cough, fatigue,...
# 24          Tinnitus  hissing, buzzing, clicking, roaring, ringing i...
# 25          Tinnitus    clicking, roaring, ringing in the ears, hissing
# 26          Tinnitus    ringing in the ears, clicking, hissing, roaring
# 27          Tinnitus     hissing, buzzing, roaring, ringing in the ears
# 28          Tinnitus                roaring, clicking, hissing, buzzing
# 29          Tinnitus     roaring, ringing in the ears, hissing, buzzing
# 30        Acetonemia             vomiting, headache, fatigue, agitation
# 31        Acetonemia                       agitation, fatigue, headache
# 32        Acetonemia                      agitation, headache, vomiting
# 33        Acetonemia                       agitation, vomiting, fatigue
# 34        Acetonemia                      vomiting, headache, agitation
# 35        Acetonemia                       agitation, fatigue, vomiting
# 36  Prostate Adenoma  frequent urination, inability to sleep through...
# 37  Prostate Adenoma  frequent urination, urinary leakage, inability...
# 38  Prostate Adenoma  frequent urination, inability to sleep through...
# 39  Prostate Adenoma  difficulty urinating, urinary leakage, inabili...
# 40  Prostate Adenoma  inability to sleep through the night without u...
# 41  Prostate Adenoma  difficulty urinating, frequent urination, urin...
# 42      Food Allergy  respiratory disorder, vomiting, rapid pulse, d...
# 43      Food Allergy  malaise, runny nose, eczema, respiratory disor...
# 44      Food Allergy  eczema, abdominal pain, low blood pressure, di...
# 45      Food Allergy  rapid pulse, abdominal pain, malaise, runny no...
# 46      Food Allergy  vomiting, respiratory disorder, runny nose, ra...
# 47      Food Allergy  rapid pulse, malaise, vomiting, eczema, respir...
# 48          Alopecia                hair loss, gradual thinning of hair
# 49          Alopecia                gradual thinning of hair, hair loss
# 50          Alopecia                gradual thinning of hair, hair loss
# 51          Alopecia                gradual thinning of hair, hair loss
# 52          Alopecia                hair loss, gradual thinning of hair
# 53          Alopecia                gradual thinning of hair, hair loss
# 54           Amnesia                disorientation in time, memory loss
# 55           Amnesia                memory loss, disorientation in time
# 56           Amnesia                disorientation in time, memory loss
# 57           Amnesia                disorientation in time, memory loss
# 58           Amnesia                disorientation in time, memory loss
# 59           Amnesia                disorientation in time, memory loss

# %%
# Create features and target
X = expanded_df['Symptoms'].apply(preprocess_symptoms)
y = expanded_df['Disease']

# %%
# Create TF-IDF features
vectorizer = TfidfVectorizer(
    max_features=500,
    min_df=1,
    max_df=0.95,
    ngram_range=(1, 2)
)

X_vectorized = vectorizer.fit_transform(X)
print(f"\nFeature matrix shape: {X_vectorized.shape}")
# Out:
# Feature matrix shape: (648, 500)

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized, y,
    test_size=0.2,
    random_state=42
)

# %%
# Train Random Forest
rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

# %%
# Fit the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200, n_jobs=-1,
#                        random_state=42)

# %%
# Make predictions
y_pred = rf_model.predict(X_test)
y_pred_proba = rf_model.predict_proba(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"\nModel Accuracy: {accuracy:.3f}")
# Out:
# Model Accuracy: 0.946

# %%
# Print detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                            precision    recall  f1-score   support
#
#                Acetonemia       1.00      1.00      1.00         2
#                  Alopecia       1.00      1.00      1.00         1
#                Amenorrhea       1.00      1.00      1.00         2
#                   Amnesia       1.00      1.00      1.00         3
#                Andropause       1.00      1.00      1.00         3
#           Angina Pectoris       1.00      1.00      1.00         3
#                   Angioma       1.00      1.00      1.00         1
#                  Anorexia       1.00      1.00      1.00         1
#                    Anuria       1.00      1.00      1.00         3
#                   Anxiety       1.00      1.00      1.00         1
#              Appendicitis       1.00      1.00      1.00         3
#                    Asthma       1.00      1.00      1.00         2
#                    Autism       1.00      1.00      1.00         1
#                  Cataract       1.00      1.00      1.00         2
#                    Cavity       1.00      1.00      1.00         1
#                 Cellulite       1.00      1.00      1.00         1
#                 Cirrhosis       1.00      1.00      1.00         1
#                   Colitis       1.00      1.00      1.00         1
#            Conjunctivitis       1.00      1.00      1.00         1
#              Constipation       1.00      1.00      1.00         2
#            Dental Abscess       1.00      1.00      1.00         3
#                       Flu       1.00      1.00      1.00         2
#              Food Allergy       1.00      1.00      1.00         1
#           Gastroenteritis       1.00      1.00      1.00         1
#                Gingivitis       1.00      1.00      1.00         2
#                 Gonorrhea       1.00      1.00      1.00         3
#                 Heartburn       1.00      1.00      1.00         2
#               Heat Stroke       1.00      1.00      1.00         3
#                    Hernia       1.00      1.00      1.00         2
#                    Herpes       0.00      0.00      0.00         0
#               Hot Flashes       1.00      1.00      1.00         1
#           Hyperthyroidism       1.00      1.00      1.00         1
#               Hypotension       1.00      1.00      1.00         1
#            Hypothyroidism       1.00      1.00      1.00         2
#              Infant Colic       1.00      1.00      1.00         1
#  Irritable Bowel Syndrome       1.00      1.00      1.00         4
#             Kidney Stones       1.00      1.00      1.00         2
#              Liver Cancer       1.00      1.00      1.00         1
#               Lung Cancer       1.00      1.00      1.00         1
#                     Lupus       1.00      1.00      1.00         1
#                   Malaria       1.00      1.00      1.00         1
#                 Menopause       1.00      1.00      1.00         2
#                  Migraine       1.00      1.00      1.00         1
#               Muscle Tear       1.00      1.00      1.00         1
#              Osteoporosis       1.00      1.00      1.00         2
#                    Otitis       1.00      1.00      1.00         1
#              Ovarian Cyst       1.00      1.00      1.00         1
#         Pancreatic Cancer       1.00      1.00      1.00         2
#              Pancreatitis       1.00      1.00      1.00         1
#                 Parkinson       1.00      1.00      1.00         1
#              Pneumothorax       1.00      1.00      1.00         1
#          Prostate Adenoma       1.00      0.50      0.67         2
#           Prostate Cancer       1.00      1.00      1.00         1
#                 Psoriasis       1.00      0.50      0.67         2
#               Renal Colic       0.67      1.00      0.80         2
#      Rheumatoid Arthritis       1.00      1.00      1.00         2
#                   Scabies       1.00      1.00      1.00         3
#                  Sciatica       1.00      1.00      1.00         1
#                 Sinusitis       1.00      1.00      1.00         1
#              Skin Abscess       1.00      1.00      1.00         1
#                Stuttering       1.00      1.00      1.00         3
#               Tachycardia       1.00      1.00      1.00         1
#                  Tinnitus       1.00      1.00      1.00         1
#               Tonsillitis       1.00      0.67      0.80         3
#                 Toothache       1.00      1.00      1.00         1
#            Trichomoniasis       0.00      0.00      0.00         0
#                     Ulcer       1.00      1.00      1.00         3
#      Urinary Incontinence       0.50      1.00      0.67         1
#   Urinary Tract Infection       1.00      0.75      0.86         4
#                 Urticaria       0.50      1.00      0.67         1
#            Varicose Veins       1.00      0.67      0.80         3
#                   Vertigo       1.00      1.00      1.00         2
# Viral or Bacterial Angina       0.50      1.00      0.67         1
#      Vitamin C Deficiency       1.00      1.00      1.00         3
#                     Warts       1.00      1.00      1.00         1
#            Whooping Cough       1.00      1.00      1.00         2
#           Yeast Infection       0.00      0.00      0.00         2
#
#                  accuracy                           0.95       130
#                 macro avg       0.94      0.94      0.93       130
#              weighted avg       0.97      0.95      0.95       130
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ** Create a function that dictates how the model will handle inputs and outputs**

# %%
#  Make  a definition for disease predictions and suggest additional symptoms to look for.
def predict_disease(symptoms, confidence_threshold=0.30):

    # Define medical phrases that should be preserved
    medical_phrases = [
        'pain in the chest',
        'shortness of breath',
        'ringing in the ears',
        'swelling of the joints',
        'pain in my right hand',
        'burning sensation in the chest',
        'difficulty in breathing',
        'loss of voice',
        'loss of height',
        'loss of appetite',
        'thinning of hair',
        'disorientation in time',
        'inability to sleep',
        'sensitivity to light',
        'shortness of breath on exertion'
        'burning sensation in the sternum',
        'bitter or sour taste',
        'difficulty establishing contact',
        'absence of gas',
        'absence of bowel movements',
        'shortness of breath on exertion',
        'pain in the chest',
        'chest pain',
        'shortness of breath',
        'ringing in the ears',
        'swelling of the joints',
        'pain in my right hand',
        'burning sensation in the chest',
        'difficulty in breathing',
        'loss of voice',
        'loss of height',
        'loss of appetite',
        'thinning of hair',
        'disorientation in time',
        'inability to sleep',
        'sensitivity to light',
        'burning sensation in the sternum',
        'bitter or sour taste',
        'difficulty establishing contact',
        'absence of gas',
        'absence of bowel movements',
        'bleeding outside menstruation',
        'difficulty breathing',
        'pain in the back',
        'back pain',
        'swelling of the joints',
        'joint swelling',
        'pain in the right hand',
        'right hand pain',
        'pain in the left hand',
        'left hand pain',
        'loss of appetite',
        'difficulty swallowing',
        'ringing in the ears',
        'blurred vision',
        'high blood pressure',
        'low blood pressure',
        'rapid heart rate',
        'irregular heartbeat',
        'muscle weakness',
        'chronic fatigue',
        'night sweats',
        'weight loss',
        'weight gain',
        'joint pain',
        'muscle pain',
        'sore throat',
        'runny nose',
        'stuffy nose',
        'abdominal pain',
        'stomach pain',
        'lower back pain',
        'upper back pain',
        'neck pain',
        'shoulder pain'
        'bleeding outside menstruation'
    ]
    
    # Preprocess symptoms
    processed_symptoms = preprocess_symptoms(symptoms)
    
    # Split input symptoms into a list while preserving phrases
    temp_text = processed_symptoms
    for phrase in medical_phrases:
        if phrase in temp_text:
            temp_text = temp_text.replace(phrase, phrase.replace(' ', '_'))
    
    input_symptoms = set()
    for symptom in temp_text.split():
        if '_' in symptom:
            # Convert back underscores to spaces for preserved phrases
            input_symptoms.add(symptom.replace('_', ' '))
        else:
            input_symptoms.add(symptom)
    
    # Get all known symptoms from the vectorizer
    known_symptoms = set(vectorizer.get_feature_names_out())
    
    # Check if there are any known symptoms in the input
    matching_symptoms = input_symptoms.intersection(known_symptoms)
    
    # Create a dictionary of all diseases and their symptoms from your original dataset
    disease_symptom_map = {}
    for _, row in disease_symptoms_data.iterrows():
        disease = row['Disease']
        # Process symptoms while preserving phrases
        temp_symptoms = preprocess_symptoms(row['Symptoms'])
        for phrase in medical_phrases:
            if phrase in temp_symptoms:
                temp_symptoms = temp_symptoms.replace(phrase, phrase.replace(' ', '_'))
        
        all_symptoms = set()
        for symptom in temp_symptoms.split():
            if '_' in symptom:
                all_symptoms.add(symptom.replace('_', ' '))
            else:
                all_symptoms.add(symptom)
        
        disease_symptom_map[disease] = all_symptoms
    
    # Vectorize
    X_new = vectorizer.transform([processed_symptoms])

    # Get probabilities
    proba = rf_model.predict_proba(X_new)[0]

    # Get all predictions with their probabilities
    predictions = []
    for idx, probability in enumerate(proba):
        disease = rf_model.classes_[idx]
        predictions.append((disease, probability))
    
    # Sort by probability
    predictions.sort(key=lambda x: x[1], reverse=True)
    
    # Format output
    output = "Based on the symptoms you described:\n\n"
    output += f"Your symptoms: {', '.join(sorted(input_symptoms))}\n\n"
    
    # Add predictions with additional symptoms
    output += "Possible conditions and related symptoms to watch for:\n\n"
    
    for disease, prob in predictions[:3]:  # Show top 3 predictions
        # Get all symptoms for this disease
        disease_symptoms = disease_symptom_map.get(disease, set())
        
        # Find symptoms not mentioned by the user
        missing_symptoms = disease_symptoms - input_symptoms
        
        # Calculate symptom match percentage
        if disease_symptoms:
            match_percentage = len(input_symptoms.intersection(disease_symptoms)) / len(disease_symptoms) * 100
        else:    
            match_percentage = 0

        output += f"▶ {disease} (Confidence: {prob:.1%}, Symptom Match: {match_percentage:.0f}%)\n"
        
        if missing_symptoms:
            output += "   Additional symptoms to look for:\n"
            # Sort missing symptoms to ensure consistent output
            sorted_missing = sorted(missing_symptoms)
            output += "   • " + "\n   • ".join(sorted_missing) + "\n"
        else:
            output += "   ✓ All typical symptoms present\n"
        output += "\n"
    
    output += "\nImportant Notes:\n"
    output += "• The presence of additional symptoms may increase or decrease the likelihood of each condition\n"
    output += "• Some symptoms may be more significant than others for specific conditions\n"
    output += "• This is not a medical diagnosis - please consult a healthcare professional\n"
    
    return output

# %% [markdown]
# ** Save the Model **

# %%
# Save the model
model_components = {
    'model': rf_model,
    'vectorizer': vectorizer
}
joblib.dump(model_components, 'disease_prediction_model.joblib')
# Out:
# ['disease_prediction_model.joblib']

# %% [markdown]
# ** Model Testing **

# %%
# Verify model and vectorizer are loaded
print("Model loaded:", rf_model is not None)
print("Vectorizer loaded:", vectorizer is not None)
# Out:
# Model loaded: True
# Vectorizer loaded: True

# %%
# 1. Basic Model Testing
def test_model():
    """Test the model with various symptom combinations"""
    print("Testing Disease Prediction Model")
    print("=" * 50)
    
    # Test cases
    test_cases = [
        "fever, cough, headache",
        "joint pain, swelling, redness",
        "nausea, vomiting, dizziness",
        "chest pain, shortness of breath",
        "headache, blurred vision, dizziness"
    ]
    
    for symptoms in test_cases:
        print(f"\nTest Case: {symptoms}")
        print("-" * 50)
        
        # Get predictions
        result = predict_disease(symptoms)
        print(result)
        print("\n")

# %%
# 2. Test Edge Cases
def test_edge_cases():

    print("Testing Edge Cases")
    print("=" * 50)
    
    edge_cases = [
        "",  # Empty input
        "nonexistent symptom",  # Invalid symptom
        "fever",  # Single symptom
        "FEVER, COUGH, HEADACHE",  # All caps
        "fever,cough,headache",  # No spaces
        "   fever,    cough,   headache   "  # Extra spaces
    ]
    
    for case in edge_cases:
        print(f"\nEdge Case: '{case}'")
        print("-" * 50)
        try:
            result = predict_disease(case)
            print(result)
        except Exception as e:
            print(f"Error: {str(e)}")
        print("\n")

# %%
# 3. Test Real-World Scenarios
def test_real_scenarios():
    """Test with real-world symptom combinations"""
    print("Testing Real-World Scenarios")
    print("=" * 50)
    
    scenarios = [
        # Common cold symptoms
        "runny nose, sore throat, cough, mild fever",
        # Flu-like symptoms
        "high fever, body aches, fatigue, headache",
        # Allergic reaction
        "rash, itching, swelling, difficulty breathing",
        # Digestive issues
        "nausea, vomiting, abdominal pain, diarrhea"
    ]
    
    for scenario in scenarios:
        print(f"\nScenario: {scenario}")
        print("-" * 50)
        result = predict_disease(scenario)
        print(result)
        print("\n")

# %%
# Run all tests
print("Running Model Tests...")
print("\n1. Basic Model Testing")
test_model()

print("\n2. Edge Case Testing")
test_edge_cases()

print("\n3. Real-World Scenario Testing")
test_real_scenarios()
# Out:
# Running Model Tests...
#
# 1. Basic Model Testing
# Testing Disease Prediction Model
# ==================================================
#
# Test Case: fever, cough, headache
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: cough, fever, headache
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Malaria (Confidence: 66.0%, Symptom Match: 60%)
#    Additional symptoms to look for:
#    • vomiting
#    • weakness
#
# ▶ Toothache (Confidence: 9.0%, Symptom Match: 50%)
#    Additional symptoms to look for:
#    • pain
#    • swelling
#
# ▶ Measles (Confidence: 8.0%, Symptom Match: 33%)
#    Additional symptoms to look for:
#    • conjunctivitis
#    • rash
#    • red
#    • rhinitis
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Test Case: joint pain, swelling, redness
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: joint pain, redness, swelling
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Gout (Confidence: 30.0%, Symptom Match: 33%)
#    Additional symptoms to look for:
#    • fever
#    • joint
#    • pain
#    • stiffness
#
# ▶ Lyme Disease (Confidence: 23.5%, Symptom Match: 14%)
#    Additional symptoms to look for:
#    • fatigue
#    • fever
#    • headache
#    • neck
#    • rash
#    • stiffness
#
# ▶ Urticaria (Confidence: 7.0%, Symptom Match: 50%)
#    Additional symptoms to look for:
#    • hives
#    • itching
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Test Case: nausea, vomiting, dizziness
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: dizziness, nausea, vomiting
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Vertigo (Confidence: 31.0%, Symptom Match: 75%)
#    Additional symptoms to look for:
#    • headache
#
# ▶ Glaucoma (Confidence: 14.0%, Symptom Match: 22%)
#    Additional symptoms to look for:
#    • around
#    • blurred vision
#    • eye
#    • halos
#    • lights
#    • pain
#    • redness
#
# ▶ Hypotension (Confidence: 13.5%, Symptom Match: 40%)
#    Additional symptoms to look for:
#    • blurred vision
#    • fainting
#    • fatigue
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Test Case: chest pain, shortness of breath
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: chest pain, shortness of breath
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Hypertension (Confidence: 42.5%, Symptom Match: 40%)
#    Additional symptoms to look for:
#    • dizziness
#    • headache
#    • nosebleeds
#
# ▶ Pneumothorax (Confidence: 26.5%, Symptom Match: 40%)
#    Additional symptoms to look for:
#    • cough
#    • heartbeat
#    • rapid
#
# ▶ Tachycardia (Confidence: 17.0%, Symptom Match: 40%)
#    Additional symptoms to look for:
#    • dizziness
#    • heartbeat
#    • rapid
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Test Case: headache, blurred vision, dizziness
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: blurred vision, dizziness, headache
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Heat Stroke (Confidence: 38.5%, Symptom Match: 38%)
#    Additional symptoms to look for:
#    • drowsiness
#    • fever
#    • intense
#    • sweating
#    • thirst
#
# ▶ Hypotension (Confidence: 35.5%, Symptom Match: 40%)
#    Additional symptoms to look for:
#    • fainting
#    • fatigue
#    • nausea
#
# ▶ Vertigo (Confidence: 8.0%, Symptom Match: 50%)
#    Additional symptoms to look for:
#    • nausea
#    • vomiting
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# 2. Edge Case Testing
# Testing Edge Cases
# ==================================================
#
# Edge Case: ''
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms:
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Cirrhosis (Confidence: 7.5%, Symptom Match: 0%)
#    Additional symptoms to look for:
#    • abdomen
#    • abnormal
#    • accumulation
#    • bleeding
#    • digestive
#    • fluid
#    • itching
#    • jaundice
#
# ▶ Tinnitus (Confidence: 7.0%, Symptom Match: 0%)
#    Additional symptoms to look for:
#    • buzzing
#    • clicking
#    • hissing
#    • ringing in the ears
#    • roaring
#
# ▶ Sciatica (Confidence: 6.0%, Symptom Match: 0%)
#    Additional symptoms to look for:
#    • muscle weakness
#    • numbness
#    • pain
#    • tingling
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Edge Case: 'nonexistent symptom'
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: nonexistent, symptom
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Cirrhosis (Confidence: 7.5%, Symptom Match: 0%)
#    Additional symptoms to look for:
#    • abdomen
#    • abnormal
#    • accumulation
#    • bleeding
#    • digestive
#    • fluid
#    • itching
#    • jaundice
#
# ▶ Tinnitus (Confidence: 7.0%, Symptom Match: 0%)
#    Additional symptoms to look for:
#    • buzzing
#    • clicking
#    • hissing
#    • ringing in the ears
#    • roaring
#
# ▶ Sciatica (Confidence: 6.0%, Symptom Match: 0%)
#    Additional symptoms to look for:
#    • muscle weakness
#    • numbness
#    • pain
#    • tingling
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Edge Case: 'fever'
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: fever
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Anthrax (Confidence: 22.5%, Symptom Match: 25%)
#    Additional symptoms to look for:
#    • chills
#    • lethargy
#    • malaise
#
# ▶ Toothache (Confidence: 18.5%, Symptom Match: 25%)
#    Additional symptoms to look for:
#    • headache
#    • pain
#    • swelling
#
# ▶ Liver Cancer (Confidence: 9.0%, Symptom Match: 25%)
#    Additional symptoms to look for:
#    • abdominal pain
#    • peritonitis
#    • weight loss
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Edge Case: 'FEVER, COUGH, HEADACHE'
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: cough, fever, headache
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Malaria (Confidence: 66.0%, Symptom Match: 60%)
#    Additional symptoms to look for:
#    • vomiting
#    • weakness
#
# ▶ Toothache (Confidence: 9.0%, Symptom Match: 50%)
#    Additional symptoms to look for:
#    • pain
#    • swelling
#
# ▶ Measles (Confidence: 8.0%, Symptom Match: 33%)
#    Additional symptoms to look for:
#    • conjunctivitis
#    • rash
#    • red
#    • rhinitis
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Edge Case: 'fever,cough,headache'
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: cough, fever, headache
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Malaria (Confidence: 66.0%, Symptom Match: 60%)
#    Additional symptoms to look for:
#    • vomiting
#    • weakness
#
# ▶ Toothache (Confidence: 9.0%, Symptom Match: 50%)
#    Additional symptoms to look for:
#    • pain
#    • swelling
#
# ▶ Measles (Confidence: 8.0%, Symptom Match: 33%)
#    Additional symptoms to look for:
#    • conjunctivitis
#    • rash
#    • red
#    • rhinitis
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Edge Case: '   fever,    cough,   headache   '
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: cough, fever, headache
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Malaria (Confidence: 66.0%, Symptom Match: 60%)
#    Additional symptoms to look for:
#    • vomiting
#    • weakness
#
# ▶ Toothache (Confidence: 9.0%, Symptom Match: 50%)
#    Additional symptoms to look for:
#    • pain
#    • swelling
#
# ▶ Measles (Confidence: 8.0%, Symptom Match: 33%)
#    Additional symptoms to look for:
#    • conjunctivitis
#    • rash
#    • red
#    • rhinitis
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# 3. Real-World Scenario Testing
# Testing Real-World Scenarios
# ==================================================
#
# Scenario: runny nose, sore throat, cough, mild fever
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: cough, fever, mild, runny nose, sore throat
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Whooping Cough (Confidence: 44.0%, Symptom Match: 80%)
#    Additional symptoms to look for:
#    • sneezing
#
# ▶ Viral or Bacterial Angina (Confidence: 18.0%, Symptom Match: 20%)
#    Additional symptoms to look for:
#    • and
#    • chills
#    • difficulty swallowing
#    • headache
#    • lymph
#    • nodes
#    • sweating
#    • swollen
#
# ▶ Food Allergy (Confidence: 12.0%, Symptom Match: 9%)
#    Additional symptoms to look for:
#    • abdominal pain
#    • diarrhea
#    • disorder
#    • eczema
#    • low blood pressure
#    • malaise
#    • pulse
#    • rapid
#    • respiratory
#    • vomiting
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Scenario: high fever, body aches, fatigue, headache
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: aches, body, fatigue, fever, headache, high
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Anuria (Confidence: 14.0%, Symptom Match: 12%)
#    Additional symptoms to look for:
#    • back pain
#    • high blood pressure
#    • lower
#    • nausea
#    • seizures
#    • swelling
#    • vomiting
#
# ▶ Colitis (Confidence: 13.0%, Symptom Match: 29%)
#    Additional symptoms to look for:
#    • anemia
#    • bloating
#    • constipation
#    • diarrhea
#    • pain
#
# ▶ Flu (Confidence: 11.0%, Symptom Match: 67%)
#    Additional symptoms to look for:
#    • muscle
#    • runny nose
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Scenario: rash, itching, swelling, difficulty breathing
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: difficulty breathing, itching, rash, swelling
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Angina Pectoris (Confidence: 15.5%, Symptom Match: 0%)
#    Additional symptoms to look for:
#    • anxiety
#    • breathing
#    • difficulty
#    • excessive
#    • malaise
#    • nausea
#    • sweating
#    • vomiting
#
# ▶ Muscle Tear (Confidence: 11.5%, Symptom Match: 14%)
#    Additional symptoms to look for:
#    • bruising
#    • difficulty
#    • pain
#    • popping
#    • sound
#    • walking
#
# ▶ Urticaria (Confidence: 11.5%, Symptom Match: 50%)
#    Additional symptoms to look for:
#    • hives
#    • redness
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional
#
#
#
#
# Scenario: nausea, vomiting, abdominal pain, diarrhea
# --------------------------------------------------
# Based on the symptoms you described:
#
# Your symptoms: abdominal pain, diarrhea, nausea, vomiting
#
# Possible conditions and related symptoms to watch for:
#
# ▶ Ulcer (Confidence: 22.0%, Symptom Match: 60%)
#    Additional symptoms to look for:
#    • bloating
#    • weight loss
#
# ▶ Irritable Bowel Syndrome (Confidence: 12.5%, Symptom Match: 33%)
#    Additional symptoms to look for:
#    • bloating
#    • constipation
#    • mucus
#    • stool
#
# ▶ Liver Cancer (Confidence: 11.0%, Symptom Match: 25%)
#    Additional symptoms to look for:
#    • fever
#    • peritonitis
#    • weight loss
#
#
# Important Notes:
# • The presence of additional symptoms may increase or decrease the likelihood of each condition
# • Some symptoms may be more significant than others for specific conditions
# • This is not a medical diagnosis - please consult a healthcare professional

# %% [markdown]
# ** Create the function of Speech-to-Text **

# %%
# Load Whisper Model for Speech-to-Text
model = whisper.load_model("base")

# Function to Convert Speech to Text
def transcribe(audio):
    if audio is None:
        return "No audio detected."
    audio_path = audio  # Gradio provides an audio file path
    result = model.transcribe(audio_path)
    return result["text"]

# Function to Generate AI Chatbot Response
def chatbot_response(text):
    # Simulate chatbot logic (replace with OpenAI API if needed)
    response = f"Chatbot says: {text}"  # Placeholder response
    return response

# Function to Convert Text to Speech (TTS)
def text_to_speech(text):
    tts = gTTS(text=text, lang="en")
    tts.save("response.mp3")
    return "response.mp3"

# %%
# Add the speech-to-text function 
def speech_to_text(audio):
    """Convert speech to text using speech recognition"""
    try:
        r = sr.Recognizer()
        with sr.AudioFile(audio) as source:
            audio_text = r.listen(source)
            text = r.recognize_google(audio_text)
            return text
    except Exception as e:
        return str(e)

def preprocess_symptoms(text):
    """Clean and preprocess the input symptoms"""
    if not isinstance(text, str):
        return ''
    text = re.sub(r'[\[\]\'"]', '', text)
    symptoms = [s.strip().lower() for s in text.split(',')]
    return ' '.join([s for s in symptoms if s])

# %%
# Create audio directory if it doesn't exist
AUDIO_DIR = "audio_outputs"
if not os.path.exists(AUDIO_DIR):
    os.makedirs(AUDIO_DIR)

# %% [markdown]
# **Create the function for Text-to-Speech**

# %%
# Format text to focus on symptoms and conditions while preserving medical phrases
def format_text_for_speech(text):

    # Define medical phrases that should be preserved
    medical_phrases = [
        'pain in the chest',
        'shortness of breath',
        'ringing in the ears',
        'swelling of the joints',
        'pain in my right hand',
        'burning sensation in the chest',
        'difficulty in breathing',
        'loss of voice',
        'loss of height',
        'loss of appetite',
        'thinning of hair',
        'disorientation in time',
        'inability to sleep',
        'sensitivity to light',
        'burning sensation in the sternum',
        'bitter or sour taste',
        'difficulty establishing contact',
        'absence of gas',
        'absence of bowel movements',
        'shortness of breath',
        'ringing in the ears',
        'swelling of the joints',
        'pain in my right hand',
        'burning sensation in the chest',
        'difficulty in breathing',
        'loss of voice',
        'loss of height',
        'loss of appetite',
        'thinning of hair',
        'disorientation in time',
        'inability to sleep',
        'sensitivity to light',
        'shortness of breath on exertion'
        'burning sensation in the sternum',
        'bitter or sour taste',
        'difficulty establishing contact',
        'absence of gas',
        'absence of bowel movements',
        'shortness of breath on exertion',
        'pain in the chest',
        'chest pain',
        'shortness of breath',
        'ringing in the ears',
        'swelling of the joints',
        'pain in my right hand',
        'burning sensation in the chest',
        'difficulty in breathing',
        'loss of voice',
        'loss of height',
        'loss of appetite',
        'thinning of hair',
        'disorientation in time',
        'inability to sleep',
        'sensitivity to light',
        'burning sensation in the sternum',
        'bitter or sour taste',
        'difficulty establishing contact',
        'absence of gas',
        'absence of bowel movements',
        'bleeding outside menstruation',
        'difficulty breathing',
        'pain in the back',
        'back pain',
        'swelling of the joints',
        'joint swelling',
        'pain in the right hand',
        'right hand pain',
        'pain in the left hand',
        'left hand pain',
        'loss of appetite',
        'difficulty swallowing',
        'ringing in the ears',
        'blurred vision',
        'high blood pressure',
        'low blood pressure',
        'rapid heart rate',
        'irregular heartbeat',
        'muscle weakness',
        'chronic fatigue',
        'night sweats',
        'weight loss',
        'weight gain',
        'joint pain',
        'muscle pain',
        'sore throat',
        'runny nose',
        'stuffy nose',
        'abdominal pain',
        'stomach pain',
        'lower back pain',
        'upper back pain',
        'neck pain',
        'shoulder pain'
        'bleeding outside menstruation'
    ]
        
    # Replace spaces in medical phrases with underscores
    temp_text = text
    for phrase in sorted(medical_phrases, key=len, reverse=True):  # Sort by length to handle longer phrases first
        if phrase in temp_text.lower():
            temp_text = temp_text.replace(phrase, phrase.replace(' ', '_'))
    
    lines = temp_text.split('\n')
    speech_parts = []

    for line in lines:
        if "Recognized symptoms:" in line:
            symptoms = line.split(":", 1)[1].strip()
            speech_parts.append(f"Based on your symptoms: {symptoms}")
            
        elif "Possible conditions" in line:
            speech_parts.append("Here are the most likely conditions")
            
        elif line.strip().startswith('▶'):
            # Extract condition and confidence
            condition_line = line.replace('▶', '').strip()
            condition_name = condition_line.split('(')[0].strip()
            confidence = condition_line.split('(')[1].rstrip(')')
            speech_parts.append(f"A possible condition is {condition_name}, with {confidence}")
            
        elif line.strip().startswith('•'):
            # Handle bullet points for additional symptoms
            symptom = line.replace('•', '').strip()
            if symptom:
                # Convert underscores back to spaces for speech
                symptom = symptom.replace('_', ' ')
                speech_parts.append(symptom)
    
    # Join all parts and convert any remaining underscores back to spaces
    speech_text = ". ".join(speech_parts)
    speech_text = speech_text.replace('_', ' ')
    
    return speech_text

# %% [markdown]
# ** Test Text-to-Speech **

# %%
# Test text to speech
test_text = """Recognized symptoms: pain in the chest, shortness of breath, difficulty in breathing

Possible conditions:

▶ Angina (85% confidence)
Additional symptoms:
• burning sensation in the chest
• pain in the left arm
• sweating"""

formatted_text = format_text_for_speech(test_text)
print(formatted_text)
# Out:
# Based on your symptoms: pain in the chest, shortness of breath, difficulty in breathing. Here are the most likely conditions. A possible condition is Angina, with 85% confidence. burning sensation in the chest. pain in the left arm. sweating

# %%
def text_to_speech(text):
    try:
        if not text:
            return None
        
        # Format the text for better speech
        speech_text = format_text_for_speech(text)
        
        # Create a unique filename using timestamp
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        audio_file = os.path.join(AUDIO_DIR, f"audio_response_{timestamp}.mp3")
        
        # Generate speech
        tts = gTTS(text=speech_text, lang="en", slow=False)
        tts.save(audio_file)
        
        return audio_file if os.path.exists(audio_file) else None
            
    except Exception as e:
        print(f"TTS Error: {str(e)}")
        return None

# %%
# Define test text to speech testing
def test_tts():
    """Test the text-to-speech functionality"""
    test_text = """Recognized symptoms: fever, headache, cough

Possible conditions:

▶ Common Cold (85% confidence)
Additional symptoms:
• Runny nose
• Sore throat
• Fatigue"""
    
    print("Testing text-to-speech...")
    print("\nInput text:")
    print(test_text)
    
    output_file = text_to_speech(test_text)
    if output_file and os.path.exists(output_file):
        print(f"\n✓ Successfully generated audio file: {output_file}")
        print(f"✓ File size: {os.path.getsize(output_file)} bytes")
    else:
        print("\n✗ Failed to generate audio file")

# %%
# Test audio generation and playback
def test_audio_generation():

    test_text = "This is a test of the text to speech system."
    
    print("Testing audio generation...")
    audio_file = text_to_speech(test_text)
    
    if audio_file and os.path.exists(audio_file):
        print(f"✓ Audio file successfully generated: {audio_file}")
        print(f"✓ File size: {os.path.getsize(audio_file)} bytes")
    else:
        print("✗ Audio file generation failed")

# Run the test
test_audio_generation()
# Out:
# Testing audio generation...
# TTS Error: No text to speak
# ✗ Audio file generation failed

# %%
# Verify Audio Generation
def process_audio(audio):
    try:
        text = transcribe(audio)
        response = chatbot_response(text)
        speech_file = text_to_speech(response)
        
        if not verify_audio(speech_file):
            print("Audio generation failed verification")
            return text, response, None
            
        return text, response, speech_file
        
    except Exception as e:
        print(f"Error in process_audio: {str(e)}")
        return "Error processing audio", "Error", None

# %%
def transcribe(audio):
    if audio is None:
        return "No audio detected."
    audio_path = audio  # Gradio provides an audio file path
    result = model.transcribe(audio_path)
    return result["text"]

# %%
#  Verify audio file is valid
def verify_audio(audio_path):

    try:
        if not audio_path or not os.path.exists(audio_path):
            return False
            
        # Check file size
        if os.path.getsize(audio_path) < 100:  # Too small to be valid
            return False
            
        return True
    except Exception:
        return False

# %% [markdown]
# ** Create ChatBot Function **

# %%
def chatbot(message, history):
    """Chatbot function for Gradio"""
    if not message:
        return "Please enter some symptoms."
    
    try:
        return predict_disease(message)
    except Exception as e:
        return f"Error processing symptoms: {str(e)}\nPlease enter symptoms separated by commas."

# %% [markdown]
# ** Create Gradio Interface **

# %%
with gr.Blocks(theme=gr.themes.Soft()) as demo:
    gr.Markdown("""
    # Medical Symptom Checker
    Enter your symptoms below or use voice input, and I'll help identify possible conditions.
    """)
    
    with gr.Row():
        with gr.Column():
            # Text input for symptoms
            text_input = gr.Textbox(
                label="Enter symptoms",
                placeholder="Example: fever, cough, headache",
                lines=3
            )
            
            # Voice input - updated parameters
            audio_input = gr.Audio(
                label="Or describe symptoms by voice",
                type="filepath",
                sources=["microphone"],
                streaming=False
            )
            
            with gr.Row():
                check_button = gr.Button("Check Symptoms")
        
        with gr.Column():
            # Analysis results output
            output = gr.Textbox(
                label="Analysis Results",
                lines=15
            )
            
            # Audio output for TTS
            with gr.Row():
                tts_button = gr.Button("🔊 Listen to Results")
                audio_output = gr.Audio(label="Audio Results")
    
    # Set up event handlers
    check_button.click(
        fn=chatbot,
        inputs=[text_input],
        outputs=[output]
    )
    
    # Auto-transcribe when audio is recorded
    audio_input.change(
        fn=transcribe,
        inputs=[audio_input],
        outputs=[text_input]
    )
    
    tts_button.click(
        fn=text_to_speech,
        inputs=[output],
        outputs=[audio_output]
    )
    
    # Add examples
    gr.Examples(
        examples=[
            ["fever, cough, headache"],
            ["joint pain, swelling, redness"],
            ["nausea, vomiting, dizziness"]
        ],
        inputs=text_input
    )

    # Add detailed disclaimer
    gr.Markdown("""
    ### Important Notes:
    - This tool helps identify potential conditions based on symptoms
    - For each condition, additional symptoms are listed to help you better understand what to look for
    - The confidence score indicates how well your symptoms match known patterns
    - The symptom match percentage shows how many of the typical symptoms you're experiencing
    - This is not a diagnostic tool - always consult healthcare professionals for proper medical evaluation
    """)
# Out:
# c:\Users\Sami\anaconda3\Lib\site-packages\gradio\utils.py:1017: UserWarning: Expected 2 arguments for function <function chatbot at 0x0000021C57C35760>, received 1.
#   warnings.warn(
# c:\Users\Sami\anaconda3\Lib\site-packages\gradio\utils.py:1021: UserWarning: Expected at least 2 arguments for function <function chatbot at 0x0000021C57C35760>, received 1.
#   warnings.warn(

# %% [markdown]
# ** Launch the application **

# %%
# Launch the interface
if __name__ == "__main__":
    demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Tuning the parameters for the model using GridSearchCV

# %%
# Improving RF model with GSCV
# Create the parameter grid for the GridSearchCV model running Random Forest
param_grid_rf = {
    'n_estimators': [50, 100, 200],  # Number of trees in the forest
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider at each split
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum number of samples required to be at a leaf node
    'class_weight': [None, 'balanced'], # Adjust weights inversely proportional to class frequencies
    'bootstrap': [True, False]  # Whether bootstrap samples are used when building trees
}

# create the grid_tuned model and the grid search estimator
grid_model_rf = RandomForestClassifier()
grid_clf_rf = GridSearchCV(grid_model_rf, param_grid_rf, verbose=3)

# Fit the model by using the grid search estimator.
# This will take the Random Forest model and try each combination of parameters.
grid_clf_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1296 candidates, totalling 6480 fits
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=auto, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.923 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.933 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.923 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.942 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.903 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.942 total time=   0.2s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.942 total time=   0.2s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.922 total time=   0.1s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.913 total time=   0.1s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.971 total time=   0.4s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.933 total time=   0.4s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.932 total time=   0.4s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.903 total time=   0.4s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.952 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.952 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.913 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.922 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=50;, score=0.903 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.971 total time=   0.1s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.942 total time=   0.1s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.942 total time=   0.1s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.922 total time=   0.1s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.883 total time=   0.1s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.4s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.952 total time=   0.3s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.962 total time=   0.3s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.922 total time=   0.3s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.913 total time=   0.4s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.923 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.894 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.933 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.893 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=50;, score=0.883 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.942 total time=   0.1s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.933 total time=   0.1s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.933 total time=   0.1s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.903 total time=   0.1s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100;, score=0.893 total time=   0.1s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.952 total time=   0.3s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.933 total time=   0.3s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.894 total time=   0.3s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.922 total time=   0.3s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=200;, score=0.893 total time=   0.3s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.952 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.933 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.894 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.893 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=50;, score=0.883 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.942 total time=   0.1s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.942 total time=   0.1s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.904 total time=   0.1s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.922 total time=   0.1s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.893 total time=   0.1s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.942 total time=   0.3s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.933 total time=   0.3s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.913 total time=   0.3s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.913 total time=   0.3s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.903 total time=   0.3s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.942 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.875 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.865 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.883 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.893 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.962 total time=   0.1s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.942 total time=   0.1s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.875 total time=   0.1s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.864 total time=   0.1s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.874 total time=   0.1s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.942 total time=   0.3s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.933 total time=   0.3s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.894 total time=   0.3s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.883 total time=   0.3s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.864 total time=   0.3s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.894 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.875 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.885 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.883 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.854 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.913 total time=   0.1s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.904 total time=   0.1s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.875 total time=   0.1s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.893 total time=   0.1s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.874 total time=   0.1s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.913 total time=   0.3s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.923 total time=   0.3s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.875 total time=   0.3s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.883 total time=   0.3s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.864 total time=   0.3s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.837 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.817 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.816 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.738 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.846 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.779 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.808 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.845 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.757 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.856 total time=   0.2s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.817 total time=   0.2s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.837 total time=   0.2s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.825 total time=   0.2s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.796 total time=   0.2s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.846 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.786 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.757 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.827 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.808 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.827 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.835 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.854 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.865 total time=   0.2s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.837 total time=   0.2s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.837 total time=   0.2s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.835 total time=   0.2s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.816 total time=   0.2s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.798 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.846 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.767 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.837 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.856 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.817 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.806 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.777 total time=   0.0s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.827 total time=   0.2s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.817 total time=   0.2s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.837 total time=   0.2s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.835 total time=   0.2s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.777 total time=   0.2s
# [CV 1/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.952 total time=   0.0s
# [CV 2/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.962 total time=   0.0s
# [CV 3/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.942 total time=   0.0s
# [CV 4/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.951 total time=   0.0s
# [CV 5/5] END bootstrap=True, class_weight=None, max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=50;, score=0.922 total time=   0.0s
# ...
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.865 total time=   0.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.883 total time=   0.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.845 total time=   0.2s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.856 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.798 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.760 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.825 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=50;, score=0.757 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.865 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.827 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.808 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.825 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.864 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.923 total time=   0.2s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.904 total time=   0.2s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.865 total time=   0.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.835 total time=   0.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.854 total time=   0.2s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.856 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.798 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.798 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.767 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=50;, score=0.767 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.846 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.846 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.808 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.816 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100;, score=0.796 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.865 total time=   0.2s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.846 total time=   0.2s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.875 total time=   0.2s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.903 total time=   0.2s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=200;, score=0.864 total time=   0.2s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.837 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.817 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.806 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=50;, score=0.757 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.856 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.894 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.817 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.825 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=100;, score=0.796 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.875 total time=   0.2s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.875 total time=   0.1s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.808 total time=   0.1s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.816 total time=   0.1s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=2, n_estimators=200;, score=0.806 total time=   0.1s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.808 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.846 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.750 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.825 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=50;, score=0.777 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.894 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.885 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.817 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.806 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=100;, score=0.816 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.875 total time=   0.1s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.894 total time=   0.1s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.856 total time=   0.1s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.845 total time=   0.1s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=5, n_estimators=200;, score=0.786 total time=   0.1s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.846 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.865 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.798 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.786 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=50;, score=0.748 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.913 total time=   0.0s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.865 total time=   0.0s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.798 total time=   0.0s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.816 total time=   0.0s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=100;, score=0.767 total time=   0.0s
# [CV 1/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.885 total time=   0.1s
# [CV 2/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.865 total time=   0.1s
# [CV 3/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.837 total time=   0.1s
# [CV 4/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.854 total time=   0.1s
# [CV 5/5] END bootstrap=False, class_weight=balanced, max_depth=30, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=200;, score=0.796 total time=   0.1s
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 2160 fits failed out of a total of 6480.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2160 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan ... 0.80871919 0.83188947 0.84740478]
#   warnings.warn(
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'bootstrap': [True, False],
#                          'class_weight': [None, 'balanced'],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
# List the best parameters for this dataset
print(f"Best Parameters for the Random Forest model is: \n{grid_clf_rf.best_params_}")

# Create Predictions with the best model
grid_y_pred_rf = grid_clf_rf.predict(X_test)

# Print the classification report for the best model
class_report_rf = classification_report(y_test, grid_y_pred_rf)
print(f"\n Classification Report for the best Random Forest model is: \n{class_report_rf}")

# Print the best models score
print(f"\n Random Forest Model Best Score is: {grid_clf_rf.best_score_}")

# Calculate Accuracy Score for the best model
accuracy_rf_best = accuracy_score(y_test, grid_y_pred_rf)
print(f"\n Accuracy Score for the best Random Forest model: {accuracy_rf_best}")
# Out:
# Best Parameters for the Random Forest model is:
# {'bootstrap': True, 'class_weight': 'balanced', 'max_depth': 30, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
#  Classification Report for the best Random Forest model is:
#                            precision    recall  f1-score   support
#
#                Acetonemia       1.00      1.00      1.00         2
#                  Alopecia       1.00      1.00      1.00         1
#                Amenorrhea       1.00      1.00      1.00         2
#                   Amnesia       1.00      1.00      1.00         3
#                Andropause       1.00      1.00      1.00         3
#           Angina Pectoris       1.00      1.00      1.00         3
#                   Angioma       1.00      1.00      1.00         1
#                  Anorexia       1.00      1.00      1.00         1
#                    Anuria       1.00      1.00      1.00         3
#                   Anxiety       1.00      1.00      1.00         1
#              Appendicitis       1.00      1.00      1.00         3
#                    Asthma       1.00      1.00      1.00         2
#                    Autism       1.00      1.00      1.00         1
#                  Cataract       1.00      1.00      1.00         2
#                    Cavity       1.00      1.00      1.00         1
#                 Cellulite       1.00      1.00      1.00         1
#                 Cirrhosis       1.00      1.00      1.00         1
#                   Colitis       1.00      1.00      1.00         1
#            Conjunctivitis       1.00      1.00      1.00         1
#              Constipation       1.00      1.00      1.00         2
#            Dental Abscess       1.00      1.00      1.00         3
#                       Flu       1.00      1.00      1.00         2
#              Food Allergy       1.00      1.00      1.00         1
#           Gastroenteritis       1.00      1.00      1.00         1
#                Gingivitis       1.00      1.00      1.00         2
#                 Gonorrhea       1.00      1.00      1.00         3
#                 Heartburn       1.00      1.00      1.00         2
#               Heat Stroke       1.00      1.00      1.00         3
#                    Hernia       1.00      1.00      1.00         2
#                    Herpes       0.00      0.00      0.00         0
#               Hot Flashes       1.00      1.00      1.00         1
#           Hyperthyroidism       1.00      1.00      1.00         1
#               Hypotension       1.00      1.00      1.00         1
#            Hypothyroidism       1.00      1.00      1.00         2
#              Infant Colic       1.00      1.00      1.00         1
#  Irritable Bowel Syndrome       1.00      1.00      1.00         4
#             Kidney Stones       1.00      1.00      1.00         2
#              Liver Cancer       1.00      1.00      1.00         1
#               Lung Cancer       1.00      1.00      1.00         1
#                     Lupus       1.00      1.00      1.00         1
#                   Malaria       1.00      1.00      1.00         1
#                 Menopause       1.00      1.00      1.00         2
#                  Migraine       1.00      1.00      1.00         1
#               Muscle Tear       1.00      1.00      1.00         1
#              Osteoporosis       1.00      1.00      1.00         2
#                    Otitis       1.00      1.00      1.00         1
#              Ovarian Cyst       1.00      1.00      1.00         1
#         Pancreatic Cancer       1.00      1.00      1.00         2
#              Pancreatitis       1.00      1.00      1.00         1
#                 Parkinson       1.00      1.00      1.00         1
#              Pneumothorax       1.00      1.00      1.00         1
#          Prostate Adenoma       1.00      0.50      0.67         2
#           Prostate Cancer       1.00      1.00      1.00         1
#                 Psoriasis       1.00      0.50      0.67         2
#               Renal Colic       1.00      1.00      1.00         2
#      Rheumatoid Arthritis       1.00      1.00      1.00         2
#                   Scabies       1.00      1.00      1.00         3
#                  Sciatica       1.00      1.00      1.00         1
#                 Sinusitis       1.00      1.00      1.00         1
#              Skin Abscess       1.00      1.00      1.00         1
#                Stuttering       1.00      1.00      1.00         3
#               Tachycardia       1.00      1.00      1.00         1
#                  Tinnitus       1.00      1.00      1.00         1
#               Tonsillitis       1.00      0.67      0.80         3
#                 Toothache       1.00      1.00      1.00         1
#            Trichomoniasis       0.00      0.00      0.00         0
#                     Ulcer       1.00      1.00      1.00         3
#      Urinary Incontinence       0.50      1.00      0.67         1
#   Urinary Tract Infection       1.00      1.00      1.00         4
#                 Urticaria       0.50      1.00      0.67         1
#            Varicose Veins       1.00      0.67      0.80         3
#                   Vertigo       1.00      1.00      1.00         2
# Viral or Bacterial Angina       0.50      1.00      0.67         1
#      Vitamin C Deficiency       1.00      1.00      1.00         3
#                     Warts       1.00      1.00      1.00         1
#            Whooping Cough       1.00      1.00      1.00         2
#           Yeast Infection       1.00      0.50      0.67         2
#
#                  accuracy                           0.96       130
#                 macro avg       0.95      0.95      0.94       130
#              weighted avg       0.99      0.96      0.97       130
#
#
#  Random Forest Model Best Score is: 0.961370425690814
#
#  Accuracy Score for the best Random Forest model: 0.9615384615384616
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Sami\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
